# %% [markdown]
# # Day 2 RNN

# %% [markdown]
# ### Importing libraries

# %%
# Libraries

import random

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, SimpleRNN, LSTM, GRU
from tensorflow.keras.callbacks import EarlyStopping

random.seed(42)
np.random.seed(42)
tf.random.set_seed(42)

# %% [markdown]
# ### Load & inspect data

# %%
# Load and inspect Bitcoin data

bitcoin = pd.read_csv("../data/dc.csv")

bitcoin = bitcoin.rename(
    columns={"Unnamed: 0": "date"}
)

bitcoin["date"] = pd.to_datetime(bitcoin["date"])

bitcoin = (
    bitcoin
    .sort_values("date")
    .reset_index(drop=True)
)

print(bitcoin.shape)

bitcoin.head()
# Out:
# (1000, 6)
#         date  open_USD  high_USD  low_USD  close_USD  volume
# 0 2018-05-07   9661.02   9689.67  9181.00    9365.00   33787
# 1 2018-05-08   9365.00   9475.70  9060.54    9187.56   25533
# 2 2018-05-09   9178.00   9390.00  8965.00    9310.00   25673
# 3 2018-05-10   9310.00   9395.12  8970.00    9002.20   25055
# 4 2018-05-11   9002.21   9016.80  8341.00    8400.00   48227

# %%
# Basic inspection

bitcoin.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       1000 non-null   datetime64[us]
#  1   open_USD   1000 non-null   float64
#  2   high_USD   1000 non-null   float64
#  3   low_USD    1000 non-null   float64
#  4   close_USD  1000 non-null   float64
#  5   volume     1000 non-null   int64
# dtypes: datetime64[us](1), float64(4), int64(1)
# memory usage: 47.0 KB

# %%
# Summary statistics

bitcoin.describe()
# Out:
#                       date      open_USD      high_USD       low_USD  \
# count                 1000   1000.000000   1000.000000   1000.000000
# mean   2019-09-18 12:00:00   9285.762120   9542.880270   9011.393200
# min    2018-05-07 00:00:00   3211.710000   3276.500000   3156.260000
# 25%    2019-01-11 18:00:00   6467.192500   6582.255000   6325.015000
# 50%    2019-09-18 12:00:00   8189.695000   8351.630000   8002.045000
# 75%    2020-05-25 06:00:00  10216.860000  10419.562500   9907.977500
# max    2021-01-30 00:00:00  40586.960000  41950.000000  38720.000000
# std                    NaN   5793.522832   6075.604427   5483.524463
#
#           close_USD         volume
# count   1000.000000    1000.000000
# mean    9310.335850   53100.498000
# min     3211.720000    5743.000000
# 25%     6466.762500   30045.750000
# 50%     8189.330000   43795.500000
# 75%    10220.170000   64909.250000
# max    40582.810000  402201.000000
# std     5846.917681   35329.832031

# %% [markdown]
# Visualizing the target variable

# %%
# Visualize closing price over time

plt.figure(figsize=(10, 4))

plt.plot(
    bitcoin["date"],
    bitcoin["close_USD"]
)

plt.title("Bitcoin Closing Price Over Time")
plt.xlabel("Date")
plt.ylabel("Close Price (USD)")

plt.ticklabel_format(
    style="plain",
    axis="y"
)

plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# ### Preparing data for recurrent modeling

# %%
# Prepare Bitcoin data for recurrent models

features = [
    "open_USD",
    "high_USD",
    "low_USD",
    "close_USD",
    "volume"
]

target_col = "close_USD"

bitcoin_model = bitcoin[["date"] + features].copy()

print("Unique dates:", bitcoin_model["date"].nunique())
print("Rows:", len(bitcoin_model))

scaler_bitcoin = MinMaxScaler(feature_range=(0, 1))

scaled_features = scaler_bitcoin.fit_transform(
    bitcoin_model[features]
)

look_back = 10                                                  # use 10 previous days to predict next close

target_index = features.index(target_col)
# Out:
# Unique dates: 1000
# Rows: 1000

# %% [markdown]
# ### Useful functions

# %%
# Function to create recurrent sequence windows

def create_sequences(dataset, target_index, look_back=10):

    X, y = [], []

    for i in range(len(dataset) - look_back):

        X.append(
            dataset[i:i + look_back, :]
        )                                                       # previous look_back days

        y.append(
            dataset[i + look_back, target_index]
        )                                                       # next day's close_USD

    return np.array(X), np.array(y)

# %%
# Function to visualize training curves

def plot_training_curves(history, title):

    fig, axes = plt.subplots(1, 2, figsize=(12, 4))

    # Loss
    axes[0].plot(
        history.history["loss"],
        label="Training Loss"
    )

    axes[0].plot(
        history.history["val_loss"],
        label="Validation Loss"
    )

    axes[0].set_title(title + " Loss")
    axes[0].set_xlabel("Epoch")
    axes[0].set_ylabel("MSE Loss")

    axes[0].legend()

    # MAE
    axes[1].plot(
        history.history["mean_absolute_error"],
        label="Training MAE"
    )

    axes[1].plot(
        history.history["val_mean_absolute_error"],
        label="Validation MAE"
    )

    axes[1].set_title(title + " MAE")
    axes[1].set_xlabel("Epoch")
    axes[1].set_ylabel("Mean Absolute Error")

    axes[1].legend()

    plt.tight_layout()

    plt.show()

# %%
# Function to evaluate forecasting performance

def evaluate_and_plot(
    model,
    trainX,
    testX,
    trainY,
    testY,
    scaler,
    target_index,
    title
):

    # Predictions
    train_pred = model.predict(trainX)
    test_pred = model.predict(testX)

    # Create arrays for inverse scaling
    train_dummy = np.zeros((len(train_pred), len(features)))
    test_dummy = np.zeros((len(test_pred), len(features)))

    train_dummy[:, target_index] = train_pred.flatten()
    test_dummy[:, target_index] = test_pred.flatten()

    trainY_dummy = np.zeros((len(trainY), len(features)))
    testY_dummy = np.zeros((len(testY), len(features)))

    trainY_dummy[:, target_index] = trainY
    testY_dummy[:, target_index] = testY

    # Inverse transform
    train_pred_inv = scaler.inverse_transform(train_dummy)[:, target_index]
    test_pred_inv = scaler.inverse_transform(test_dummy)[:, target_index]

    trainY_inv = scaler.inverse_transform(trainY_dummy)[:, target_index]
    testY_inv = scaler.inverse_transform(testY_dummy)[:, target_index]

    # Metrics
    train_rmse = np.sqrt(mean_squared_error(trainY_inv, train_pred_inv))
    test_rmse = np.sqrt(mean_squared_error(testY_inv, test_pred_inv))

    train_mae = mean_absolute_error(trainY_inv, train_pred_inv)
    test_mae = mean_absolute_error(testY_inv, test_pred_inv)

    print(f"{title} Train RMSE: {train_rmse:.2f}")
    print(f"{title} Test RMSE: {test_rmse:.2f}")

    print(f"{title} Train MAE: {train_mae:.2f}")
    print(f"{title} Test MAE: {test_mae:.2f}")

    # Plot predictions
    plt.figure(figsize=(10, 4))

    plt.plot(
        testY_inv,
        label="Actual"
    )

    plt.plot(
        test_pred_inv,
        label="Predicted"
    )

    plt.title(title + " Test Predictions")

    plt.xlabel("Test time index")
    plt.ylabel("Bitcoin Close Price (USD)")

    plt.ticklabel_format(
        style="plain",
        axis="y"
    )

    plt.legend()

    plt.show()

# %%
# Function to compare model metrics

def evaluate_metrics(
    model,
    testX,
    testY,
    scaler,
    target_index
):

    test_pred = model.predict(testX)

    test_dummy = np.zeros((len(test_pred), len(features)))
    test_dummy[:, target_index] = test_pred.flatten()

    testY_dummy = np.zeros((len(testY), len(features)))
    testY_dummy[:, target_index] = testY

    test_pred_inv = scaler.inverse_transform(test_dummy)[:, target_index]
    testY_inv = scaler.inverse_transform(testY_dummy)[:, target_index]

    rmse = np.sqrt(mean_squared_error(testY_inv, test_pred_inv))
    mae = mean_absolute_error(testY_inv, test_pred_inv)

    return rmse, mae

# %% [markdown]
# ### Creating train/test recurrent tensors

# %%
# Create train/test recurrent tensors

train_size = int(len(scaled_features) * 0.8)                    # chronological 80/20 split

train_bitcoin = scaled_features[:train_size]                    # earlier data
test_bitcoin = scaled_features[train_size:]                     # held-out future data

trainX_bitcoin, trainY_bitcoin = create_sequences(
    train_bitcoin,
    target_index,
    look_back
)

testX_bitcoin, testY_bitcoin = create_sequences(
    test_bitcoin,
    target_index,
    look_back
)

print("trainX_bitcoin shape:", trainX_bitcoin.shape)
print("testX_bitcoin shape:", testX_bitcoin.shape)
print("trainY_bitcoin shape:", trainY_bitcoin.shape)
print("testY_bitcoin shape:", testY_bitcoin.shape)
# Out:
# trainX_bitcoin shape: (790, 10, 5)
# testX_bitcoin shape: (190, 10, 5)
# trainY_bitcoin shape: (790,)
# testY_bitcoin shape: (190,)

# %% [markdown]
# ### Baseline SimpleRNN model

# %%
# Build and train baseline SimpleRNN model

simple_rnn_model = Sequential([
    SimpleRNN(
        8,                                     # small baseline recurrent layer
        activation="tanh",                     # standard activation for SimpleRNN
        input_shape=(look_back, trainX_bitcoin.shape[2])
    ),                                         # input shape = timesteps, features

    Dense(1)                                   # output layer: predict next close_USD value
])

simple_rnn_model.compile(
    optimizer="adam",                          # adaptive gradient-based optimizer
    loss="mean_squared_error",                 # regression loss
    metrics=["mean_absolute_error"]            # easier-to-interpret training metric
)

simple_rnn_history = simple_rnn_model.fit(
    trainX_bitcoin,
    trainY_bitcoin,
    epochs=50,                                 # baseline training limit
    batch_size=16,                             # update weights after each batch
    validation_split=0.2,                      # last 20% of training data used for validation
    shuffle=False,                             # preserve chronological order
    verbose=1
)
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Epoch 1/50
# c:\Users\ivpri\gsb545\.venv_clean\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0108 - mean_absolute_error: 0.0820 - val_loss: 0.0113 - val_mean_absolute_error: 0.0747
# Epoch 2/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0041 - mean_absolute_error: 0.0477 - val_loss: 0.0080 - val_mean_absolute_error: 0.0571
# Epoch 3/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0029 - mean_absolute_error: 0.0402 - val_loss: 0.0062 - val_mean_absolute_error: 0.0496
# Epoch 4/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0022 - mean_absolute_error: 0.0343 - val_loss: 0.0049 - val_mean_absolute_error: 0.0438
# Epoch 5/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0018 - mean_absolute_error: 0.0304 - val_loss: 0.0039 - val_mean_absolute_error: 0.0391
# Epoch 6/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0015 - mean_absolute_error: 0.0279 - val_loss: 0.0032 - val_mean_absolute_error: 0.0353
# Epoch 7/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0013 - mean_absolute_error: 0.0259 - val_loss: 0.0026 - val_mean_absolute_error: 0.0323
# Epoch 8/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0011 - mean_absolute_error: 0.0242 - val_loss: 0.0022 - val_mean_absolute_error: 0.0299
# Epoch 9/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.6651e-04 - mean_absolute_error: 0.0227 - val_loss: 0.0019 - val_mean_absolute_error: 0.0280
# Epoch 10/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.5578e-04 - mean_absolute_error: 0.0214 - val_loss: 0.0016 - val_mean_absolute_error: 0.0264
# Epoch 11/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.6079e-04 - mean_absolute_error: 0.0202 - val_loss: 0.0014 - val_mean_absolute_error: 0.0250
# Epoch 12/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.7854e-04 - mean_absolute_error: 0.0191 - val_loss: 0.0013 - val_mean_absolute_error: 0.0239
# Epoch 13/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.0700e-04 - mean_absolute_error: 0.0181 - val_loss: 0.0012 - val_mean_absolute_error: 0.0228
# Epoch 14/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.4465e-04 - mean_absolute_error: 0.0172 - val_loss: 0.0010 - val_mean_absolute_error: 0.0218
# Epoch 15/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.9029e-04 - mean_absolute_error: 0.0163 - val_loss: 9.4630e-04 - val_mean_absolute_error: 0.0208
# Epoch 16/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.4292e-04 - mean_absolute_error: 0.0155 - val_loss: 8.6039e-04 - val_mean_absolute_error: 0.0199
# Epoch 17/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0168e-04 - mean_absolute_error: 0.0148 - val_loss: 7.8424e-04 - val_mean_absolute_error: 0.0190
# Epoch 18/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6580e-04 - mean_absolute_error: 0.0141 - val_loss: 7.1639e-04 - val_mean_absolute_error: 0.0182
# Epoch 19/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3461e-04 - mean_absolute_error: 0.0135 - val_loss: 6.5577e-04 - val_mean_absolute_error: 0.0174
# Epoch 20/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.0751e-04 - mean_absolute_error: 0.0130 - val_loss: 6.0155e-04 - val_mean_absolute_error: 0.0166
# Epoch 21/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.8395e-04 - mean_absolute_error: 0.0125 - val_loss: 5.5307e-04 - val_mean_absolute_error: 0.0159
# Epoch 22/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6346e-04 - mean_absolute_error: 0.0121 - val_loss: 5.0976e-04 - val_mean_absolute_error: 0.0153
# Epoch 23/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.4563e-04 - mean_absolute_error: 0.0116 - val_loss: 4.7113e-04 - val_mean_absolute_error: 0.0147
# Epoch 24/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3011e-04 - mean_absolute_error: 0.0113 - val_loss: 4.3671e-04 - val_mean_absolute_error: 0.0142
# Epoch 25/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1657e-04 - mean_absolute_error: 0.0109 - val_loss: 4.0610e-04 - val_mean_absolute_error: 0.0137
# Epoch 26/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0475e-04 - mean_absolute_error: 0.0106 - val_loss: 3.7890e-04 - val_mean_absolute_error: 0.0133
# Epoch 27/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9443e-04 - mean_absolute_error: 0.0104 - val_loss: 3.5479e-04 - val_mean_absolute_error: 0.0129
# Epoch 28/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8540e-04 - mean_absolute_error: 0.0101 - val_loss: 3.3342e-04 - val_mean_absolute_error: 0.0125
# Epoch 29/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7750e-04 - mean_absolute_error: 0.0099 - val_loss: 3.1452e-04 - val_mean_absolute_error: 0.0122
# Epoch 30/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7058e-04 - mean_absolute_error: 0.0097 - val_loss: 2.9782e-04 - val_mean_absolute_error: 0.0118
# Epoch 31/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6452e-04 - mean_absolute_error: 0.0095 - val_loss: 2.8306e-04 - val_mean_absolute_error: 0.0115
# Epoch 32/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5921e-04 - mean_absolute_error: 0.0093 - val_loss: 2.7003e-04 - val_mean_absolute_error: 0.0113
# Epoch 33/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5456e-04 - mean_absolute_error: 0.0091 - val_loss: 2.5853e-04 - val_mean_absolute_error: 0.0110
# Epoch 34/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5048e-04 - mean_absolute_error: 0.0090 - val_loss: 2.4838e-04 - val_mean_absolute_error: 0.0108
# Epoch 35/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4691e-04 - mean_absolute_error: 0.0089 - val_loss: 2.3943e-04 - val_mean_absolute_error: 0.0106
# Epoch 36/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4377e-04 - mean_absolute_error: 0.0087 - val_loss: 2.3152e-04 - val_mean_absolute_error: 0.0104
# Epoch 37/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4101e-04 - mean_absolute_error: 0.0086 - val_loss: 2.2454e-04 - val_mean_absolute_error: 0.0102
# Epoch 38/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3859e-04 - mean_absolute_error: 0.0085 - val_loss: 2.1838e-04 - val_mean_absolute_error: 0.0100
# Epoch 39/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3646e-04 - mean_absolute_error: 0.0085 - val_loss: 2.1293e-04 - val_mean_absolute_error: 0.0099
# Epoch 40/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3457e-04 - mean_absolute_error: 0.0084 - val_loss: 2.0810e-04 - val_mean_absolute_error: 0.0098
# Epoch 41/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3290e-04 - mean_absolute_error: 0.0083 - val_loss: 2.0383e-04 - val_mean_absolute_error: 0.0097
# Epoch 42/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3141e-04 - mean_absolute_error: 0.0083 - val_loss: 2.0004e-04 - val_mean_absolute_error: 0.0096
# Epoch 43/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3007e-04 - mean_absolute_error: 0.0082 - val_loss: 1.9668e-04 - val_mean_absolute_error: 0.0095
# Epoch 44/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2886e-04 - mean_absolute_error: 0.0082 - val_loss: 1.9370e-04 - val_mean_absolute_error: 0.0094
# Epoch 45/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2777e-04 - mean_absolute_error: 0.0081 - val_loss: 1.9105e-04 - val_mean_absolute_error: 0.0094
# Epoch 46/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2677e-04 - mean_absolute_error: 0.0081 - val_loss: 1.8868e-04 - val_mean_absolute_error: 0.0093
# Epoch 47/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2584e-04 - mean_absolute_error: 0.0080 - val_loss: 1.8659e-04 - val_mean_absolute_error: 0.0093
# Epoch 48/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2498e-04 - mean_absolute_error: 0.0080 - val_loss: 1.8472e-04 - val_mean_absolute_error: 0.0092
# Epoch 49/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2417e-04 - mean_absolute_error: 0.0080 - val_loss: 1.8307e-04 - val_mean_absolute_error: 0.0092
# Epoch 50/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2341e-04 - mean_absolute_error: 0.0079 - val_loss: 1.8160e-04 - val_mean_absolute_error: 0.0091

# %% [markdown]
# Visualizing training

# %%
# Visualize SimpleRNN training performance

plot_training_curves(
    simple_rnn_history,
    "Baseline SimpleRNN"
)

# %% [markdown]
# Evaluation on test data

# %%
# Evaluate SimpleRNN on held-out future test data

evaluate_and_plot(
    simple_rnn_model,
    trainX_bitcoin,
    testX_bitcoin,
    trainY_bitcoin,
    testY_bitcoin,
    scaler_bitcoin,
    target_index,
    "Baseline SimpleRNN"
)
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Baseline SimpleRNN Train RMSE: 493.52
# Baseline SimpleRNN Test RMSE: 3953.11
# Baseline SimpleRNN Train MAE: 364.83
# Baseline SimpleRNN Test MAE: 2409.82

# %% [markdown]
# ### Baseline LSTM Model

# %%
# Build and train baseline LSTM model

lstm_model = Sequential([
    LSTM(
        8,                                     # small baseline LSTM layer
        activation="tanh",                     # standard LSTM hidden-state activation
        input_shape=(look_back, trainX_bitcoin.shape[2])
    ),                                         # input shape = timesteps, features

    Dense(1)                                   # output layer: predict next close_USD value
])

lstm_model.compile(
    optimizer="adam",                          # adaptive gradient-based optimizer
    loss="mean_squared_error",                 # regression loss
    metrics=["mean_absolute_error"]            # easier-to-interpret training metric
)

lstm_history = lstm_model.fit(
    trainX_bitcoin,
    trainY_bitcoin,
    epochs=50,                                 # baseline training limit
    batch_size=16,                             # update weights after each batch
    validation_split=0.2,                      # last 20% of training data used for validation
    shuffle=False,                             # preserve chronological order
    verbose=1
)
# Out:
# Epoch 1/50
# c:\Users\ivpri\gsb545\.venv_clean\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0018 - mean_absolute_error: 0.0332 - val_loss: 0.0052 - val_mean_absolute_error: 0.0536
# Epoch 2/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0011 - mean_absolute_error: 0.0257 - val_loss: 0.0043 - val_mean_absolute_error: 0.0484
# Epoch 3/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.7141e-04 - mean_absolute_error: 0.0183 - val_loss: 0.0033 - val_mean_absolute_error: 0.0409
# Epoch 4/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8698e-04 - mean_absolute_error: 0.0150 - val_loss: 0.0024 - val_mean_absolute_error: 0.0340
# Epoch 5/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.2297e-04 - mean_absolute_error: 0.0139 - val_loss: 0.0019 - val_mean_absolute_error: 0.0293
# Epoch 6/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.8944e-04 - mean_absolute_error: 0.0132 - val_loss: 0.0015 - val_mean_absolute_error: 0.0259
# Epoch 7/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6544e-04 - mean_absolute_error: 0.0126 - val_loss: 0.0012 - val_mean_absolute_error: 0.0231
# Epoch 8/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.4755e-04 - mean_absolute_error: 0.0122 - val_loss: 9.9588e-04 - val_mean_absolute_error: 0.0206
# Epoch 9/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.3489e-04 - mean_absolute_error: 0.0118 - val_loss: 8.1265e-04 - val_mean_absolute_error: 0.0184
# Epoch 10/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2655e-04 - mean_absolute_error: 0.0116 - val_loss: 6.7026e-04 - val_mean_absolute_error: 0.0165
# Epoch 11/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2148e-04 - mean_absolute_error: 0.0114 - val_loss: 5.6249e-04 - val_mean_absolute_error: 0.0149
# Epoch 12/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1859e-04 - mean_absolute_error: 0.0112 - val_loss: 4.8299e-04 - val_mean_absolute_error: 0.0137
# Epoch 13/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.1692e-04 - mean_absolute_error: 0.0111 - val_loss: 4.2545e-04 - val_mean_absolute_error: 0.0128
# Epoch 14/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1573e-04 - mean_absolute_error: 0.0110 - val_loss: 3.8417e-04 - val_mean_absolute_error: 0.0121
# Epoch 15/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1456e-04 - mean_absolute_error: 0.0110 - val_loss: 3.5447e-04 - val_mean_absolute_error: 0.0117
# Epoch 16/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.1317e-04 - mean_absolute_error: 0.0109 - val_loss: 3.3280e-04 - val_mean_absolute_error: 0.0113
# Epoch 17/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.1150e-04 - mean_absolute_error: 0.0108 - val_loss: 3.1663e-04 - val_mean_absolute_error: 0.0110
# Epoch 18/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.0954e-04 - mean_absolute_error: 0.0108 - val_loss: 3.0425e-04 - val_mean_absolute_error: 0.0107
# Epoch 19/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0735e-04 - mean_absolute_error: 0.0107 - val_loss: 2.9449e-04 - val_mean_absolute_error: 0.0106
# Epoch 20/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0497e-04 - mean_absolute_error: 0.0106 - val_loss: 2.8657e-04 - val_mean_absolute_error: 0.0104
# Epoch 21/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.0247e-04 - mean_absolute_error: 0.0105 - val_loss: 2.7997e-04 - val_mean_absolute_error: 0.0103
# Epoch 22/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9988e-04 - mean_absolute_error: 0.0105 - val_loss: 2.7434e-04 - val_mean_absolute_error: 0.0101
# Epoch 23/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.9723e-04 - mean_absolute_error: 0.0104 - val_loss: 2.6942e-04 - val_mean_absolute_error: 0.0100
# Epoch 24/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.9457e-04 - mean_absolute_error: 0.0103 - val_loss: 2.6506e-04 - val_mean_absolute_error: 0.0100
# Epoch 25/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.9189e-04 - mean_absolute_error: 0.0102 - val_loss: 2.6112e-04 - val_mean_absolute_error: 0.0099
# Epoch 26/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.8923e-04 - mean_absolute_error: 0.0101 - val_loss: 2.5753e-04 - val_mean_absolute_error: 0.0098
# Epoch 27/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.8660e-04 - mean_absolute_error: 0.0100 - val_loss: 2.5422e-04 - val_mean_absolute_error: 0.0098
# Epoch 28/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.8401e-04 - mean_absolute_error: 0.0100 - val_loss: 2.5114e-04 - val_mean_absolute_error: 0.0097
# Epoch 29/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.8147e-04 - mean_absolute_error: 0.0099 - val_loss: 2.4826e-04 - val_mean_absolute_error: 0.0097
# Epoch 30/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.7897e-04 - mean_absolute_error: 0.0098 - val_loss: 2.4556e-04 - val_mean_absolute_error: 0.0097
# Epoch 31/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.7653e-04 - mean_absolute_error: 0.0097 - val_loss: 2.4301e-04 - val_mean_absolute_error: 0.0096
# Epoch 32/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.7416e-04 - mean_absolute_error: 0.0096 - val_loss: 2.4059e-04 - val_mean_absolute_error: 0.0096
# Epoch 33/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.7184e-04 - mean_absolute_error: 0.0096 - val_loss: 2.3830e-04 - val_mean_absolute_error: 0.0096
# Epoch 34/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6959e-04 - mean_absolute_error: 0.0095 - val_loss: 2.3612e-04 - val_mean_absolute_error: 0.0095
# Epoch 35/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6740e-04 - mean_absolute_error: 0.0094 - val_loss: 2.3405e-04 - val_mean_absolute_error: 0.0095
# Epoch 36/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.6527e-04 - mean_absolute_error: 0.0093 - val_loss: 2.3207e-04 - val_mean_absolute_error: 0.0095
# Epoch 37/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.6321e-04 - mean_absolute_error: 0.0093 - val_loss: 2.3019e-04 - val_mean_absolute_error: 0.0095
# Epoch 38/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6121e-04 - mean_absolute_error: 0.0092 - val_loss: 2.2839e-04 - val_mean_absolute_error: 0.0095
# Epoch 39/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5927e-04 - mean_absolute_error: 0.0091 - val_loss: 2.2666e-04 - val_mean_absolute_error: 0.0094
# Epoch 40/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5739e-04 - mean_absolute_error: 0.0091 - val_loss: 2.2501e-04 - val_mean_absolute_error: 0.0094
# Epoch 41/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5557e-04 - mean_absolute_error: 0.0090 - val_loss: 2.2343e-04 - val_mean_absolute_error: 0.0094
# Epoch 42/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5381e-04 - mean_absolute_error: 0.0090 - val_loss: 2.2191e-04 - val_mean_absolute_error: 0.0094
# Epoch 43/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5210e-04 - mean_absolute_error: 0.0089 - val_loss: 2.2045e-04 - val_mean_absolute_error: 0.0094
# Epoch 44/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5044e-04 - mean_absolute_error: 0.0088 - val_loss: 2.1904e-04 - val_mean_absolute_error: 0.0094
# Epoch 45/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4884e-04 - mean_absolute_error: 0.0088 - val_loss: 2.1768e-04 - val_mean_absolute_error: 0.0094
# Epoch 46/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4728e-04 - mean_absolute_error: 0.0087 - val_loss: 2.1637e-04 - val_mean_absolute_error: 0.0094
# Epoch 47/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.4577e-04 - mean_absolute_error: 0.0087 - val_loss: 2.1510e-04 - val_mean_absolute_error: 0.0094
# Epoch 48/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4431e-04 - mean_absolute_error: 0.0086 - val_loss: 2.1387e-04 - val_mean_absolute_error: 0.0094
# Epoch 49/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4289e-04 - mean_absolute_error: 0.0086 - val_loss: 2.1267e-04 - val_mean_absolute_error: 0.0094
# Epoch 50/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4151e-04 - mean_absolute_error: 0.0086 - val_loss: 2.1150e-04 - val_mean_absolute_error: 0.0094

# %% [markdown]
# Visualizing training

# %%
# Visualize LSTM training performance

plot_training_curves(
    lstm_history,
    "Baseline LSTM"
)

# %% [markdown]
# Evaluation on test data

# %%
# Evaluate LSTM on held-out future test data

evaluate_and_plot(
    lstm_model,
    trainX_bitcoin,
    testX_bitcoin,
    trainY_bitcoin,
    testY_bitcoin,
    scaler_bitcoin,
    target_index,
    "Baseline LSTM"
)
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Baseline LSTM Train RMSE: 434.39
# Baseline LSTM Test RMSE: 2398.13
# Baseline LSTM Train MAE: 299.69
# Baseline LSTM Test MAE: 1580.11

# %% [markdown]
# ### Baseline GRU model

# %%
# Build and train baseline GRU model

gru_model = Sequential([
    GRU(
        8,                                      # intentionally small baseline GRU layer
        activation="tanh",                     # standard GRU hidden-state activation
        input_shape=(look_back, trainX_bitcoin.shape[2])
    ),                                         # input shape = timesteps, features

    Dense(1)                                   # output layer: predict next close_USD value
])

gru_model.compile(
    optimizer="adam",                          # adaptive gradient-based optimizer
    loss="mean_squared_error",                 # regression loss
    metrics=["mean_absolute_error"]            # easier-to-interpret training metric
)

gru_history = gru_model.fit(
    trainX_bitcoin,
    trainY_bitcoin,
    epochs=50,                                 # baseline training limit
    batch_size=16,                             # update weights after each batch
    validation_split=0.2,                      # last 20% of training data used for validation
    shuffle=False,                             # preserve chronological order
    verbose=1
)
# Out:
# Epoch 1/50
# c:\Users\ivpri\gsb545\.venv_clean\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 0.0039 - mean_absolute_error: 0.0515 - val_loss: 0.0022 - val_mean_absolute_error: 0.0363
# Epoch 2/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0011 - mean_absolute_error: 0.0279 - val_loss: 0.0020 - val_mean_absolute_error: 0.0395
# Epoch 3/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.3650e-04 - mean_absolute_error: 0.0147 - val_loss: 8.5611e-04 - val_mean_absolute_error: 0.0239
# Epoch 4/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5692e-04 - mean_absolute_error: 0.0092 - val_loss: 3.7739e-04 - val_mean_absolute_error: 0.0138
# Epoch 5/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.6610e-04 - mean_absolute_error: 0.0093 - val_loss: 2.3522e-04 - val_mean_absolute_error: 0.0105
# Epoch 6/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.8008e-04 - mean_absolute_error: 0.0095 - val_loss: 1.7585e-04 - val_mean_absolute_error: 0.0090
# Epoch 7/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.8697e-04 - mean_absolute_error: 0.0096 - val_loss: 1.4778e-04 - val_mean_absolute_error: 0.0082
# Epoch 8/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.8542e-04 - mean_absolute_error: 0.0096 - val_loss: 1.3687e-04 - val_mean_absolute_error: 0.0079
# Epoch 9/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.7644e-04 - mean_absolute_error: 0.0094 - val_loss: 1.3468e-04 - val_mean_absolute_error: 0.0080
# Epoch 10/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.6288e-04 - mean_absolute_error: 0.0091 - val_loss: 1.3660e-04 - val_mean_absolute_error: 0.0083
# Epoch 11/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4787e-04 - mean_absolute_error: 0.0087 - val_loss: 1.4010e-04 - val_mean_absolute_error: 0.0085
# Epoch 12/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.3379e-04 - mean_absolute_error: 0.0083 - val_loss: 1.4387e-04 - val_mean_absolute_error: 0.0088
# Epoch 13/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2194e-04 - mean_absolute_error: 0.0080 - val_loss: 1.4737e-04 - val_mean_absolute_error: 0.0090
# Epoch 14/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.1275e-04 - mean_absolute_error: 0.0076 - val_loss: 1.5053e-04 - val_mean_absolute_error: 0.0091
# Epoch 15/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0608e-04 - mean_absolute_error: 0.0074 - val_loss: 1.5349e-04 - val_mean_absolute_error: 0.0093
# Epoch 16/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0154e-04 - mean_absolute_error: 0.0072 - val_loss: 1.5648e-04 - val_mean_absolute_error: 0.0094
# Epoch 17/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.8688e-05 - mean_absolute_error: 0.0071 - val_loss: 1.5971e-04 - val_mean_absolute_error: 0.0096
# Epoch 18/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.7116e-05 - mean_absolute_error: 0.0070 - val_loss: 1.6333e-04 - val_mean_absolute_error: 0.0098
# Epoch 19/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.6518e-05 - mean_absolute_error: 0.0070 - val_loss: 1.6747e-04 - val_mean_absolute_error: 0.0100
# Epoch 20/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.6686e-05 - mean_absolute_error: 0.0070 - val_loss: 1.7219e-04 - val_mean_absolute_error: 0.0102
# Epoch 21/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.7492e-05 - mean_absolute_error: 0.0070 - val_loss: 1.7759e-04 - val_mean_absolute_error: 0.0104
# Epoch 22/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.8869e-05 - mean_absolute_error: 0.0071 - val_loss: 1.8374e-04 - val_mean_absolute_error: 0.0107
# Epoch 23/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0079e-04 - mean_absolute_error: 0.0072 - val_loss: 1.9071e-04 - val_mean_absolute_error: 0.0111
# Epoch 24/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0323e-04 - mean_absolute_error: 0.0073 - val_loss: 1.9856e-04 - val_mean_absolute_error: 0.0114
# Epoch 25/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0620e-04 - mean_absolute_error: 0.0074 - val_loss: 2.0731e-04 - val_mean_absolute_error: 0.0117
# Epoch 26/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0967e-04 - mean_absolute_error: 0.0076 - val_loss: 2.1692e-04 - val_mean_absolute_error: 0.0121
# Epoch 27/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1360e-04 - mean_absolute_error: 0.0078 - val_loss: 2.2728e-04 - val_mean_absolute_error: 0.0125
# Epoch 28/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1791e-04 - mean_absolute_error: 0.0080 - val_loss: 2.3816e-04 - val_mean_absolute_error: 0.0129
# Epoch 29/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2248e-04 - mean_absolute_error: 0.0082 - val_loss: 2.4922e-04 - val_mean_absolute_error: 0.0133
# Epoch 30/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2712e-04 - mean_absolute_error: 0.0084 - val_loss: 2.5998e-04 - val_mean_absolute_error: 0.0136
# Epoch 31/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3159e-04 - mean_absolute_error: 0.0086 - val_loss: 2.6989e-04 - val_mean_absolute_error: 0.0139
# Epoch 32/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3563e-04 - mean_absolute_error: 0.0088 - val_loss: 2.7837e-04 - val_mean_absolute_error: 0.0142
# Epoch 33/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3897e-04 - mean_absolute_error: 0.0089 - val_loss: 2.8495e-04 - val_mean_absolute_error: 0.0144
# Epoch 34/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4142e-04 - mean_absolute_error: 0.0090 - val_loss: 2.8934e-04 - val_mean_absolute_error: 0.0145
# Epoch 35/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4289e-04 - mean_absolute_error: 0.0091 - val_loss: 2.9156e-04 - val_mean_absolute_error: 0.0146
# Epoch 36/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4342e-04 - mean_absolute_error: 0.0091 - val_loss: 2.9192e-04 - val_mean_absolute_error: 0.0146
# Epoch 37/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4320e-04 - mean_absolute_error: 0.0091 - val_loss: 2.9093e-04 - val_mean_absolute_error: 0.0145
# Epoch 38/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4246e-04 - mean_absolute_error: 0.0091 - val_loss: 2.8919e-04 - val_mean_absolute_error: 0.0145
# Epoch 39/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4147e-04 - mean_absolute_error: 0.0090 - val_loss: 2.8722e-04 - val_mean_absolute_error: 0.0144
# Epoch 40/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4044e-04 - mean_absolute_error: 0.0090 - val_loss: 2.8540e-04 - val_mean_absolute_error: 0.0144
# Epoch 41/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3950e-04 - mean_absolute_error: 0.0090 - val_loss: 2.8392e-04 - val_mean_absolute_error: 0.0143
# Epoch 42/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3873e-04 - mean_absolute_error: 0.0089 - val_loss: 2.8284e-04 - val_mean_absolute_error: 0.0143
# Epoch 43/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3812e-04 - mean_absolute_error: 0.0089 - val_loss: 2.8208e-04 - val_mean_absolute_error: 0.0143
# Epoch 44/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3764e-04 - mean_absolute_error: 0.0089 - val_loss: 2.8152e-04 - val_mean_absolute_error: 0.0142
# Epoch 45/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3723e-04 - mean_absolute_error: 0.0089 - val_loss: 2.8104e-04 - val_mean_absolute_error: 0.0142
# Epoch 46/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3683e-04 - mean_absolute_error: 0.0088 - val_loss: 2.8052e-04 - val_mean_absolute_error: 0.0142
# Epoch 47/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3640e-04 - mean_absolute_error: 0.0088 - val_loss: 2.7990e-04 - val_mean_absolute_error: 0.0142
# Epoch 48/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3592e-04 - mean_absolute_error: 0.0088 - val_loss: 2.7916e-04 - val_mean_absolute_error: 0.0142
# Epoch 49/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3539e-04 - mean_absolute_error: 0.0088 - val_loss: 2.7829e-04 - val_mean_absolute_error: 0.0141
# Epoch 50/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3481e-04 - mean_absolute_error: 0.0088 - val_loss: 2.7734e-04 - val_mean_absolute_error: 0.0141

# %% [markdown]
# Visualizing training

# %%
# Visualize GRU training performance

#overfitted more easily than the other two

plot_training_curves(
    gru_history,
    "Baseline GRU"
)

# %% [markdown]
# Evaluation on test data

# %%
# Evaluate GRU on held-out future test data

evaluate_and_plot(
    gru_model,
    trainX_bitcoin,
    testX_bitcoin,
    trainY_bitcoin,
    testY_bitcoin,
    scaler_bitcoin,
    target_index,
    "Baseline GRU"
)
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Baseline GRU Train RMSE: 560.80
# Baseline GRU Test RMSE: 4732.63
# Baseline GRU Train MAE: 438.16
# Baseline GRU Test MAE: 3248.33

# %% [markdown]
# ### Activity: Improving Forecasting Models
#
# Improve each of the baseline three recurrent models (SimpleRNN, LSTM, and GRU) and compare their forecasting performance against the XGBoost models shown below. You should provide the code for each improved model and include a markdown cell after each model describing what you changed, what you explored, and how the changes affected performance. After completing your experiments, provide a short overall summary discussing which approaches appeared most effective, which models were easiest or hardest to tune, and what tradeoffs you observed between model complexity, training stability, and forecasting performance.

# %%
# Your SimpleRNN code

# 1. Increased SimpleRNN units from 8 to 16
# 2. Added early stopping

early_stop = EarlyStopping(
    monitor="val_loss",
    patience=8,
    restore_best_weights=True
)

improved_simple_rnn_model = Sequential([
    SimpleRNN(
        16,
        activation="tanh",
        input_shape=(look_back, trainX_bitcoin.shape[2])
    ),
    Dense(1)
])

improved_simple_rnn_model.compile(
    optimizer="adam",
    loss="mean_squared_error",
    metrics=["mean_absolute_error"]
)

improved_simple_rnn_history = improved_simple_rnn_model.fit(
    trainX_bitcoin,
    trainY_bitcoin,
    epochs=100,
    batch_size=16,
    validation_split=0.2,
    shuffle=False,
    callbacks=[early_stop],
    verbose=1
)

plot_training_curves(
    improved_simple_rnn_history,
    "Improved SimpleRNN"
)

evaluate_and_plot(
    improved_simple_rnn_model,
    trainX_bitcoin,
    testX_bitcoin,
    trainY_bitcoin,
    testY_bitcoin,
    scaler_bitcoin,
    target_index,
    "Improved SimpleRNN"
)
# Out:
# Epoch 1/100
# c:\Users\ivpri\gsb545\.venv_clean\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 0.0463 - mean_absolute_error: 0.1663 - val_loss: 0.0167 - val_mean_absolute_error: 0.0882
# Epoch 2/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0083 - mean_absolute_error: 0.0736 - val_loss: 0.0118 - val_mean_absolute_error: 0.0755
# Epoch 3/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0041 - mean_absolute_error: 0.0495 - val_loss: 0.0086 - val_mean_absolute_error: 0.0605
# Epoch 4/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0030 - mean_absolute_error: 0.0413 - val_loss: 0.0076 - val_mean_absolute_error: 0.0566
# Epoch 5/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0027 - mean_absolute_error: 0.0394 - val_loss: 0.0071 - val_mean_absolute_error: 0.0557
# Epoch 6/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0025 - mean_absolute_error: 0.0380 - val_loss: 0.0065 - val_mean_absolute_error: 0.0537
# Epoch 7/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0023 - mean_absolute_error: 0.0361 - val_loss: 0.0058 - val_mean_absolute_error: 0.0513
# Epoch 8/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0020 - mean_absolute_error: 0.0341 - val_loss: 0.0052 - val_mean_absolute_error: 0.0486
# Epoch 9/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0018 - mean_absolute_error: 0.0322 - val_loss: 0.0046 - val_mean_absolute_error: 0.0459
# Epoch 10/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0016 - mean_absolute_error: 0.0303 - val_loss: 0.0041 - val_mean_absolute_error: 0.0433
# Epoch 11/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0014 - mean_absolute_error: 0.0286 - val_loss: 0.0036 - val_mean_absolute_error: 0.0407
# Epoch 12/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0013 - mean_absolute_error: 0.0270 - val_loss: 0.0032 - val_mean_absolute_error: 0.0382
# Epoch 13/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0011 - mean_absolute_error: 0.0255 - val_loss: 0.0028 - val_mean_absolute_error: 0.0359
# Epoch 14/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0010 - mean_absolute_error: 0.0241 - val_loss: 0.0025 - val_mean_absolute_error: 0.0337
# Epoch 15/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 9.2578e-04 - mean_absolute_error: 0.0228 - val_loss: 0.0022 - val_mean_absolute_error: 0.0316
# Epoch 16/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 8.3359e-04 - mean_absolute_error: 0.0216 - val_loss: 0.0020 - val_mean_absolute_error: 0.0296
# Epoch 17/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 7.5165e-04 - mean_absolute_error: 0.0205 - val_loss: 0.0018 - val_mean_absolute_error: 0.0277
# Epoch 18/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 6.7864e-04 - mean_absolute_error: 0.0195 - val_loss: 0.0016 - val_mean_absolute_error: 0.0260
# Epoch 19/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.1349e-04 - mean_absolute_error: 0.0185 - val_loss: 0.0014 - val_mean_absolute_error: 0.0244
# Epoch 20/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.5537e-04 - mean_absolute_error: 0.0176 - val_loss: 0.0012 - val_mean_absolute_error: 0.0229
# Epoch 21/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.0364e-04 - mean_absolute_error: 0.0168 - val_loss: 0.0011 - val_mean_absolute_error: 0.0215
# Epoch 22/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.5779e-04 - mean_absolute_error: 0.0160 - val_loss: 9.9339e-04 - val_mean_absolute_error: 0.0203
# Epoch 23/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.1740e-04 - mean_absolute_error: 0.0153 - val_loss: 8.9914e-04 - val_mean_absolute_error: 0.0193
# Epoch 24/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.8210e-04 - mean_absolute_error: 0.0147 - val_loss: 8.1965e-04 - val_mean_absolute_error: 0.0184
# Epoch 25/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.5151e-04 - mean_absolute_error: 0.0141 - val_loss: 7.5286e-04 - val_mean_absolute_error: 0.0177
# Epoch 26/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.2520e-04 - mean_absolute_error: 0.0136 - val_loss: 6.9668e-04 - val_mean_absolute_error: 0.0172
# Epoch 27/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.0273e-04 - mean_absolute_error: 0.0131 - val_loss: 6.4912e-04 - val_mean_absolute_error: 0.0168
# Epoch 28/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.8357e-04 - mean_absolute_error: 0.0127 - val_loss: 6.0844e-04 - val_mean_absolute_error: 0.0165
# Epoch 29/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6723e-04 - mean_absolute_error: 0.0124 - val_loss: 5.7317e-04 - val_mean_absolute_error: 0.0161
# Epoch 30/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5321e-04 - mean_absolute_error: 0.0120 - val_loss: 5.4220e-04 - val_mean_absolute_error: 0.0158
# Epoch 31/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.4108e-04 - mean_absolute_error: 0.0117 - val_loss: 5.1470e-04 - val_mean_absolute_error: 0.0155
# Epoch 32/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3048e-04 - mean_absolute_error: 0.0115 - val_loss: 4.9006e-04 - val_mean_absolute_error: 0.0153
# Epoch 33/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2113e-04 - mean_absolute_error: 0.0112 - val_loss: 4.6785e-04 - val_mean_absolute_error: 0.0150
# Epoch 34/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1280e-04 - mean_absolute_error: 0.0110 - val_loss: 4.4777e-04 - val_mean_absolute_error: 0.0148
# Epoch 35/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0531e-04 - mean_absolute_error: 0.0108 - val_loss: 4.2958e-04 - val_mean_absolute_error: 0.0146
# Epoch 36/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.9856e-04 - mean_absolute_error: 0.0106 - val_loss: 4.1309e-04 - val_mean_absolute_error: 0.0144
# Epoch 37/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9243e-04 - mean_absolute_error: 0.0104 - val_loss: 3.9817e-04 - val_mean_absolute_error: 0.0143
# Epoch 38/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.8686e-04 - mean_absolute_error: 0.0103 - val_loss: 3.8469e-04 - val_mean_absolute_error: 0.0141
# Epoch 39/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8178e-04 - mean_absolute_error: 0.0101 - val_loss: 3.7255e-04 - val_mean_absolute_error: 0.0140
# Epoch 40/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7716e-04 - mean_absolute_error: 0.0100 - val_loss: 3.6165e-04 - val_mean_absolute_error: 0.0139
# Epoch 41/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7294e-04 - mean_absolute_error: 0.0098 - val_loss: 3.5191e-04 - val_mean_absolute_error: 0.0138
# Epoch 42/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6911e-04 - mean_absolute_error: 0.0097 - val_loss: 3.4324e-04 - val_mean_absolute_error: 0.0137
# Epoch 43/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.6562e-04 - mean_absolute_error: 0.0096 - val_loss: 3.3556e-04 - val_mean_absolute_error: 0.0136
# Epoch 44/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.6246e-04 - mean_absolute_error: 0.0095 - val_loss: 3.2878e-04 - val_mean_absolute_error: 0.0136
# Epoch 45/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.5958e-04 - mean_absolute_error: 0.0094 - val_loss: 3.2282e-04 - val_mean_absolute_error: 0.0136
# Epoch 46/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.5696e-04 - mean_absolute_error: 0.0093 - val_loss: 3.1759e-04 - val_mean_absolute_error: 0.0135
# Epoch 47/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.5458e-04 - mean_absolute_error: 0.0093 - val_loss: 3.1300e-04 - val_mean_absolute_error: 0.0135
# Epoch 48/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.5240e-04 - mean_absolute_error: 0.0092 - val_loss: 3.0896e-04 - val_mean_absolute_error: 0.0135
# Epoch 49/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5040e-04 - mean_absolute_error: 0.0091 - val_loss: 3.0540e-04 - val_mean_absolute_error: 0.0136
# Epoch 50/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4855e-04 - mean_absolute_error: 0.0091 - val_loss: 3.0223e-04 - val_mean_absolute_error: 0.0136
# Epoch 51/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4683e-04 - mean_absolute_error: 0.0090 - val_loss: 2.9938e-04 - val_mean_absolute_error: 0.0136
# Epoch 52/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4520e-04 - mean_absolute_error: 0.0089 - val_loss: 2.9677e-04 - val_mean_absolute_error: 0.0136
# Epoch 53/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.4366e-04 - mean_absolute_error: 0.0089 - val_loss: 2.9435e-04 - val_mean_absolute_error: 0.0136
# Epoch 54/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.4218e-04 - mean_absolute_error: 0.0089 - val_loss: 2.9207e-04 - val_mean_absolute_error: 0.0136
# Epoch 55/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4075e-04 - mean_absolute_error: 0.0088 - val_loss: 2.8990e-04 - val_mean_absolute_error: 0.0136
# Epoch 56/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3936e-04 - mean_absolute_error: 0.0088 - val_loss: 2.8780e-04 - val_mean_absolute_error: 0.0136
# Epoch 57/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3800e-04 - mean_absolute_error: 0.0087 - val_loss: 2.8576e-04 - val_mean_absolute_error: 0.0135
# Epoch 58/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3667e-04 - mean_absolute_error: 0.0087 - val_loss: 2.8376e-04 - val_mean_absolute_error: 0.0135
# Epoch 59/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.3537e-04 - mean_absolute_error: 0.0086 - val_loss: 2.8181e-04 - val_mean_absolute_error: 0.0135
# Epoch 60/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3409e-04 - mean_absolute_error: 0.0086 - val_loss: 2.7988e-04 - val_mean_absolute_error: 0.0135
# Epoch 61/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3283e-04 - mean_absolute_error: 0.0085 - val_loss: 2.7801e-04 - val_mean_absolute_error: 0.0134
# Epoch 62/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3161e-04 - mean_absolute_error: 0.0085 - val_loss: 2.7617e-04 - val_mean_absolute_error: 0.0134
# Epoch 63/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3041e-04 - mean_absolute_error: 0.0085 - val_loss: 2.7438e-04 - val_mean_absolute_error: 0.0134
# Epoch 64/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2924e-04 - mean_absolute_error: 0.0084 - val_loss: 2.7265e-04 - val_mean_absolute_error: 0.0133
# Epoch 65/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2810e-04 - mean_absolute_error: 0.0084 - val_loss: 2.7098e-04 - val_mean_absolute_error: 0.0133
# Epoch 66/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2699e-04 - mean_absolute_error: 0.0084 - val_loss: 2.6938e-04 - val_mean_absolute_error: 0.0133
# Epoch 67/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2593e-04 - mean_absolute_error: 0.0083 - val_loss: 2.6785e-04 - val_mean_absolute_error: 0.0132
# Epoch 68/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2490e-04 - mean_absolute_error: 0.0083 - val_loss: 2.6639e-04 - val_mean_absolute_error: 0.0132
# Epoch 69/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2390e-04 - mean_absolute_error: 0.0083 - val_loss: 2.6501e-04 - val_mean_absolute_error: 0.0132
# Epoch 70/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2294e-04 - mean_absolute_error: 0.0082 - val_loss: 2.6370e-04 - val_mean_absolute_error: 0.0131
# Epoch 71/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2203e-04 - mean_absolute_error: 0.0082 - val_loss: 2.6247e-04 - val_mean_absolute_error: 0.0131
# Epoch 72/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2114e-04 - mean_absolute_error: 0.0082 - val_loss: 2.6131e-04 - val_mean_absolute_error: 0.0131
# Epoch 73/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2030e-04 - mean_absolute_error: 0.0081 - val_loss: 2.6023e-04 - val_mean_absolute_error: 0.0131
# Epoch 74/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1949e-04 - mean_absolute_error: 0.0081 - val_loss: 2.5922e-04 - val_mean_absolute_error: 0.0131
# Epoch 75/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1872e-04 - mean_absolute_error: 0.0081 - val_loss: 2.5828e-04 - val_mean_absolute_error: 0.0130
# Epoch 76/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1798e-04 - mean_absolute_error: 0.0081 - val_loss: 2.5741e-04 - val_mean_absolute_error: 0.0130
# Epoch 77/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1728e-04 - mean_absolute_error: 0.0080 - val_loss: 2.5659e-04 - val_mean_absolute_error: 0.0130
# Epoch 78/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1661e-04 - mean_absolute_error: 0.0080 - val_loss: 2.5583e-04 - val_mean_absolute_error: 0.0130
# Epoch 79/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1597e-04 - mean_absolute_error: 0.0080 - val_loss: 2.5513e-04 - val_mean_absolute_error: 0.0130
# Epoch 80/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1536e-04 - mean_absolute_error: 0.0080 - val_loss: 2.5447e-04 - val_mean_absolute_error: 0.0130
# Epoch 81/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1477e-04 - mean_absolute_error: 0.0080 - val_loss: 2.5385e-04 - val_mean_absolute_error: 0.0130
# Epoch 82/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1421e-04 - mean_absolute_error: 0.0079 - val_loss: 2.5327e-04 - val_mean_absolute_error: 0.0129
# Epoch 83/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1368e-04 - mean_absolute_error: 0.0079 - val_loss: 2.5273e-04 - val_mean_absolute_error: 0.0129
# Epoch 84/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1316e-04 - mean_absolute_error: 0.0079 - val_loss: 2.5220e-04 - val_mean_absolute_error: 0.0129
# Epoch 85/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1267e-04 - mean_absolute_error: 0.0079 - val_loss: 2.5170e-04 - val_mean_absolute_error: 0.0129
# Epoch 86/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1220e-04 - mean_absolute_error: 0.0079 - val_loss: 2.5121e-04 - val_mean_absolute_error: 0.0129
# Epoch 87/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1174e-04 - mean_absolute_error: 0.0079 - val_loss: 2.5074e-04 - val_mean_absolute_error: 0.0129
# Epoch 88/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1129e-04 - mean_absolute_error: 0.0079 - val_loss: 2.5026e-04 - val_mean_absolute_error: 0.0129
# Epoch 89/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1086e-04 - mean_absolute_error: 0.0078 - val_loss: 2.4979e-04 - val_mean_absolute_error: 0.0129
# Epoch 90/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1044e-04 - mean_absolute_error: 0.0078 - val_loss: 2.4931e-04 - val_mean_absolute_error: 0.0129
# Epoch 91/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1003e-04 - mean_absolute_error: 0.0078 - val_loss: 2.4882e-04 - val_mean_absolute_error: 0.0129
# Epoch 92/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0962e-04 - mean_absolute_error: 0.0078 - val_loss: 2.4831e-04 - val_mean_absolute_error: 0.0129
# Epoch 93/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0922e-04 - mean_absolute_error: 0.0078 - val_loss: 2.4778e-04 - val_mean_absolute_error: 0.0129
# Epoch 94/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0883e-04 - mean_absolute_error: 0.0078 - val_loss: 2.4724e-04 - val_mean_absolute_error: 0.0128
# Epoch 95/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.0843e-04 - mean_absolute_error: 0.0078 - val_loss: 2.4667e-04 - val_mean_absolute_error: 0.0128
# Epoch 96/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0804e-04 - mean_absolute_error: 0.0077 - val_loss: 2.4607e-04 - val_mean_absolute_error: 0.0128
# Epoch 97/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0765e-04 - mean_absolute_error: 0.0077 - val_loss: 2.4544e-04 - val_mean_absolute_error: 0.0128
# Epoch 98/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0727e-04 - mean_absolute_error: 0.0077 - val_loss: 2.4478e-04 - val_mean_absolute_error: 0.0128
# Epoch 99/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0688e-04 - mean_absolute_error: 0.0077 - val_loss: 2.4409e-04 - val_mean_absolute_error: 0.0128
# Epoch 100/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0649e-04 - mean_absolute_error: 0.0077 - val_loss: 2.4337e-04 - val_mean_absolute_error: 0.0127
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Improved SimpleRNN Train RMSE: 568.28
# Improved SimpleRNN Test RMSE: 5853.85
# Improved SimpleRNN Train MAE: 420.75
# Improved SimpleRNN Test MAE: 3886.10

# %% [markdown]
# For the improved SimpleRNN model, I increased the number of recurrent units from 8 to 16 and added early stopping. The larger recurrent layer gives the model more capacity to learn short-term Bitcoin price patterns, while early stopping helps prevent the model from continuing to train after validation loss stops improving. This is still a simple model, so it should be easier to train than LSTM or GRU, but might not capture longer-term patterns as well.

# %%
# Your LSTM code

# 1. Increased LSTM units from 8 to 16
# 2. Added early stopping

early_stop = EarlyStopping(
    monitor="val_loss",
    patience=8,
    restore_best_weights=True
)

improved_lstm_model = Sequential([
    LSTM(
        16,
        activation="tanh",
        input_shape=(look_back, trainX_bitcoin.shape[2])
    ),
    Dense(1)
])

improved_lstm_model.compile(
    optimizer="adam",
    loss="mean_squared_error",
    metrics=["mean_absolute_error"]
)

improved_lstm_history = improved_lstm_model.fit(
    trainX_bitcoin,
    trainY_bitcoin,
    epochs=100,
    batch_size=16,
    validation_split=0.2,
    shuffle=False,
    callbacks=[early_stop],
    verbose=1
)

plot_training_curves(
    improved_lstm_history,
    "Improved LSTM"
)

evaluate_and_plot(
    improved_lstm_model,
    trainX_bitcoin,
    testX_bitcoin,
    trainY_bitcoin,
    testY_bitcoin,
    scaler_bitcoin,
    target_index,
    "Improved LSTM"
)
# Out:
# Epoch 1/100
# c:\Users\ivpri\gsb545\.venv_clean\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: 0.0067 - mean_absolute_error: 0.0630 - val_loss: 9.6781e-04 - val_mean_absolute_error: 0.0254
# Epoch 2/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0032 - mean_absolute_error: 0.0472 - val_loss: 8.6875e-04 - val_mean_absolute_error: 0.0211
# Epoch 3/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0015 - mean_absolute_error: 0.0331 - val_loss: 9.1539e-04 - val_mean_absolute_error: 0.0217
# Epoch 4/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 7.4210e-04 - mean_absolute_error: 0.0218 - val_loss: 9.0611e-04 - val_mean_absolute_error: 0.0219
# Epoch 5/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.6688e-04 - mean_absolute_error: 0.0168 - val_loss: 8.3939e-04 - val_mean_absolute_error: 0.0209
# Epoch 6/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.5826e-04 - mean_absolute_error: 0.0144 - val_loss: 7.2831e-04 - val_mean_absolute_error: 0.0191
# Epoch 7/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 3.1066e-04 - mean_absolute_error: 0.0132 - val_loss: 6.0002e-04 - val_mean_absolute_error: 0.0172
# Epoch 8/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.8547e-04 - mean_absolute_error: 0.0125 - val_loss: 4.8491e-04 - val_mean_absolute_error: 0.0155
# Epoch 9/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.6887e-04 - mean_absolute_error: 0.0120 - val_loss: 3.9625e-04 - val_mean_absolute_error: 0.0141
# Epoch 10/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.5611e-04 - mean_absolute_error: 0.0117 - val_loss: 3.3216e-04 - val_mean_absolute_error: 0.0129
# Epoch 11/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.4568e-04 - mean_absolute_error: 0.0114 - val_loss: 2.8679e-04 - val_mean_absolute_error: 0.0120
# Epoch 12/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3702e-04 - mean_absolute_error: 0.0112 - val_loss: 2.5501e-04 - val_mean_absolute_error: 0.0114
# Epoch 13/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.2970e-04 - mean_absolute_error: 0.0110 - val_loss: 2.3292e-04 - val_mean_absolute_error: 0.0108
# Epoch 14/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.2342e-04 - mean_absolute_error: 0.0108 - val_loss: 2.1763e-04 - val_mean_absolute_error: 0.0103
# Epoch 15/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.1791e-04 - mean_absolute_error: 0.0106 - val_loss: 2.0706e-04 - val_mean_absolute_error: 0.0100
# Epoch 16/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.1299e-04 - mean_absolute_error: 0.0105 - val_loss: 1.9975e-04 - val_mean_absolute_error: 0.0098
# Epoch 17/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0855e-04 - mean_absolute_error: 0.0103 - val_loss: 1.9465e-04 - val_mean_absolute_error: 0.0096
# Epoch 18/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.0448e-04 - mean_absolute_error: 0.0102 - val_loss: 1.9106e-04 - val_mean_absolute_error: 0.0095
# Epoch 19/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.0072e-04 - mean_absolute_error: 0.0101 - val_loss: 1.8848e-04 - val_mean_absolute_error: 0.0095
# Epoch 20/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.9723e-04 - mean_absolute_error: 0.0100 - val_loss: 1.8658e-04 - val_mean_absolute_error: 0.0094
# Epoch 21/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.9397e-04 - mean_absolute_error: 0.0100 - val_loss: 1.8512e-04 - val_mean_absolute_error: 0.0093
# Epoch 22/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.9092e-04 - mean_absolute_error: 0.0099 - val_loss: 1.8394e-04 - val_mean_absolute_error: 0.0092
# Epoch 23/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.8804e-04 - mean_absolute_error: 0.0098 - val_loss: 1.8294e-04 - val_mean_absolute_error: 0.0092
# Epoch 24/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.8532e-04 - mean_absolute_error: 0.0097 - val_loss: 1.8204e-04 - val_mean_absolute_error: 0.0091
# Epoch 25/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.8273e-04 - mean_absolute_error: 0.0097 - val_loss: 1.8119e-04 - val_mean_absolute_error: 0.0091
# Epoch 26/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.8025e-04 - mean_absolute_error: 0.0096 - val_loss: 1.8036e-04 - val_mean_absolute_error: 0.0090
# Epoch 27/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.7787e-04 - mean_absolute_error: 0.0096 - val_loss: 1.7953e-04 - val_mean_absolute_error: 0.0089
# Epoch 28/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.7556e-04 - mean_absolute_error: 0.0095 - val_loss: 1.7870e-04 - val_mean_absolute_error: 0.0089
# Epoch 29/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.7331e-04 - mean_absolute_error: 0.0095 - val_loss: 1.7785e-04 - val_mean_absolute_error: 0.0088
# Epoch 30/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.7111e-04 - mean_absolute_error: 0.0094 - val_loss: 1.7701e-04 - val_mean_absolute_error: 0.0088
# Epoch 31/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.6895e-04 - mean_absolute_error: 0.0094 - val_loss: 1.7616e-04 - val_mean_absolute_error: 0.0088
# Epoch 32/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.6682e-04 - mean_absolute_error: 0.0093 - val_loss: 1.7531e-04 - val_mean_absolute_error: 0.0088
# Epoch 33/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.6472e-04 - mean_absolute_error: 0.0093 - val_loss: 1.7448e-04 - val_mean_absolute_error: 0.0087
# Epoch 34/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.6264e-04 - mean_absolute_error: 0.0092 - val_loss: 1.7366e-04 - val_mean_absolute_error: 0.0087
# Epoch 35/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.6057e-04 - mean_absolute_error: 0.0092 - val_loss: 1.7287e-04 - val_mean_absolute_error: 0.0087
# Epoch 36/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5853e-04 - mean_absolute_error: 0.0091 - val_loss: 1.7211e-04 - val_mean_absolute_error: 0.0087
# Epoch 37/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.5650e-04 - mean_absolute_error: 0.0090 - val_loss: 1.7138e-04 - val_mean_absolute_error: 0.0087
# Epoch 38/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5449e-04 - mean_absolute_error: 0.0090 - val_loss: 1.7069e-04 - val_mean_absolute_error: 0.0087
# Epoch 39/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5249e-04 - mean_absolute_error: 0.0089 - val_loss: 1.7004e-04 - val_mean_absolute_error: 0.0088
# Epoch 40/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5052e-04 - mean_absolute_error: 0.0089 - val_loss: 1.6944e-04 - val_mean_absolute_error: 0.0088
# Epoch 41/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4857e-04 - mean_absolute_error: 0.0088 - val_loss: 1.6888e-04 - val_mean_absolute_error: 0.0088
# Epoch 42/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.4664e-04 - mean_absolute_error: 0.0088 - val_loss: 1.6838e-04 - val_mean_absolute_error: 0.0088
# Epoch 43/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4473e-04 - mean_absolute_error: 0.0087 - val_loss: 1.6793e-04 - val_mean_absolute_error: 0.0089
# Epoch 44/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.4285e-04 - mean_absolute_error: 0.0087 - val_loss: 1.6754e-04 - val_mean_absolute_error: 0.0089
# Epoch 45/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.4100e-04 - mean_absolute_error: 0.0086 - val_loss: 1.6720e-04 - val_mean_absolute_error: 0.0089
# Epoch 46/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.3917e-04 - mean_absolute_error: 0.0085 - val_loss: 1.6693e-04 - val_mean_absolute_error: 0.0089
# Epoch 47/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3738e-04 - mean_absolute_error: 0.0085 - val_loss: 1.6671e-04 - val_mean_absolute_error: 0.0090
# Epoch 48/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.3562e-04 - mean_absolute_error: 0.0084 - val_loss: 1.6655e-04 - val_mean_absolute_error: 0.0090
# Epoch 49/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.3390e-04 - mean_absolute_error: 0.0084 - val_loss: 1.6645e-04 - val_mean_absolute_error: 0.0090
# Epoch 50/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3221e-04 - mean_absolute_error: 0.0083 - val_loss: 1.6642e-04 - val_mean_absolute_error: 0.0090
# Epoch 51/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.3056e-04 - mean_absolute_error: 0.0083 - val_loss: 1.6644e-04 - val_mean_absolute_error: 0.0090
# Epoch 52/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.2896e-04 - mean_absolute_error: 0.0082 - val_loss: 1.6651e-04 - val_mean_absolute_error: 0.0091
# Epoch 53/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.2739e-04 - mean_absolute_error: 0.0082 - val_loss: 1.6664e-04 - val_mean_absolute_error: 0.0091
# Epoch 54/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.2586e-04 - mean_absolute_error: 0.0081 - val_loss: 1.6682e-04 - val_mean_absolute_error: 0.0091
# Epoch 55/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.2438e-04 - mean_absolute_error: 0.0081 - val_loss: 1.6704e-04 - val_mean_absolute_error: 0.0092
# Epoch 56/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2294e-04 - mean_absolute_error: 0.0080 - val_loss: 1.6730e-04 - val_mean_absolute_error: 0.0092
# Epoch 57/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.2154e-04 - mean_absolute_error: 0.0080 - val_loss: 1.6759e-04 - val_mean_absolute_error: 0.0093
# Epoch 58/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.2018e-04 - mean_absolute_error: 0.0079 - val_loss: 1.6790e-04 - val_mean_absolute_error: 0.0093
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Improved LSTM Train RMSE: 419.44
# Improved LSTM Test RMSE: 2103.85
# Improved LSTM Train MAE: 295.06
# Improved LSTM Test MAE: 1399.85

# %% [markdown]
# For the improved LSTM model, I increased the number of units from 8 to 16 and added early stopping. LSTM models are designed to handle sequence memory better than a basic SimpleRNN, so this model should theoretically be better at learning time-dependent Bitcoin price patterns. However, LSTM models are also more complex and can take longer to train. The main goal was to see whether the added recurrent memory improved test RMSE and MAE compared with the baseline LSTM and improved SimpleRNN.

# %%
# Your GRU code

# 1. Increased GRU units from 8 to 16
# 2. Added early stopping

early_stop = EarlyStopping(
    monitor="val_loss",
    patience=8,
    restore_best_weights=True
)

improved_gru_model = Sequential([
    GRU(
        16,
        activation="tanh",
        input_shape=(look_back, trainX_bitcoin.shape[2])
    ),
    Dense(1)
])

improved_gru_model.compile(
    optimizer="adam",
    loss="mean_squared_error",
    metrics=["mean_absolute_error"]
)

improved_gru_history = improved_gru_model.fit(
    trainX_bitcoin,
    trainY_bitcoin,
    epochs=100,
    batch_size=16,
    validation_split=0.2,
    shuffle=False,
    callbacks=[early_stop],
    verbose=1
)

plot_training_curves(
    improved_gru_history,
    "Improved GRU"
)

evaluate_and_plot(
    improved_gru_model,
    trainX_bitcoin,
    testX_bitcoin,
    trainY_bitcoin,
    testY_bitcoin,
    scaler_bitcoin,
    target_index,
    "Improved GRU"
)
# Out:
# Epoch 1/100
# c:\Users\ivpri\gsb545\.venv_clean\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 9.5774e-04 - mean_absolute_error: 0.0254 - val_loss: 7.3016e-04 - val_mean_absolute_error: 0.0225
# Epoch 2/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.1116e-04 - mean_absolute_error: 0.0154 - val_loss: 4.5155e-04 - val_mean_absolute_error: 0.0155
# Epoch 3/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.3558e-04 - mean_absolute_error: 0.0137 - val_loss: 3.6424e-04 - val_mean_absolute_error: 0.0131
# Epoch 4/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.6691e-04 - mean_absolute_error: 0.0122 - val_loss: 2.8994e-04 - val_mean_absolute_error: 0.0109
# Epoch 5/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.2382e-04 - mean_absolute_error: 0.0111 - val_loss: 2.4669e-04 - val_mean_absolute_error: 0.0097
# Epoch 6/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.9285e-04 - mean_absolute_error: 0.0103 - val_loss: 2.1824e-04 - val_mean_absolute_error: 0.0090
# Epoch 7/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.7067e-04 - mean_absolute_error: 0.0097 - val_loss: 2.0000e-04 - val_mean_absolute_error: 0.0088
# Epoch 8/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.5450e-04 - mean_absolute_error: 0.0092 - val_loss: 1.8835e-04 - val_mean_absolute_error: 0.0087
# Epoch 9/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.4280e-04 - mean_absolute_error: 0.0088 - val_loss: 1.8093e-04 - val_mean_absolute_error: 0.0087
# Epoch 10/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.3442e-04 - mean_absolute_error: 0.0085 - val_loss: 1.7617e-04 - val_mean_absolute_error: 0.0087
# Epoch 11/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.2853e-04 - mean_absolute_error: 0.0083 - val_loss: 1.7305e-04 - val_mean_absolute_error: 0.0088
# Epoch 12/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.2448e-04 - mean_absolute_error: 0.0081 - val_loss: 1.7092e-04 - val_mean_absolute_error: 0.0088
# Epoch 13/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.2174e-04 - mean_absolute_error: 0.0080 - val_loss: 1.6941e-04 - val_mean_absolute_error: 0.0089
# Epoch 14/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.1990e-04 - mean_absolute_error: 0.0079 - val_loss: 1.6829e-04 - val_mean_absolute_error: 0.0089
# Epoch 15/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.1866e-04 - mean_absolute_error: 0.0079 - val_loss: 1.6740e-04 - val_mean_absolute_error: 0.0090
# Epoch 16/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.1777e-04 - mean_absolute_error: 0.0079 - val_loss: 1.6660e-04 - val_mean_absolute_error: 0.0090
# Epoch 17/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.1707e-04 - mean_absolute_error: 0.0078 - val_loss: 1.6584e-04 - val_mean_absolute_error: 0.0090
# Epoch 18/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.1648e-04 - mean_absolute_error: 0.0078 - val_loss: 1.6506e-04 - val_mean_absolute_error: 0.0091
# Epoch 19/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.1592e-04 - mean_absolute_error: 0.0078 - val_loss: 1.6424e-04 - val_mean_absolute_error: 0.0091
# Epoch 20/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.1538e-04 - mean_absolute_error: 0.0078 - val_loss: 1.6337e-04 - val_mean_absolute_error: 0.0091
# Epoch 21/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.1484e-04 - mean_absolute_error: 0.0078 - val_loss: 1.6245e-04 - val_mean_absolute_error: 0.0091
# Epoch 22/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.1429e-04 - mean_absolute_error: 0.0078 - val_loss: 1.6151e-04 - val_mean_absolute_error: 0.0091
# Epoch 23/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.1372e-04 - mean_absolute_error: 0.0077 - val_loss: 1.6055e-04 - val_mean_absolute_error: 0.0091
# Epoch 24/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.1314e-04 - mean_absolute_error: 0.0077 - val_loss: 1.5957e-04 - val_mean_absolute_error: 0.0091
# Epoch 25/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1254e-04 - mean_absolute_error: 0.0077 - val_loss: 1.5860e-04 - val_mean_absolute_error: 0.0091
# Epoch 26/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1192e-04 - mean_absolute_error: 0.0077 - val_loss: 1.5764e-04 - val_mean_absolute_error: 0.0091
# Epoch 27/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1128e-04 - mean_absolute_error: 0.0077 - val_loss: 1.5670e-04 - val_mean_absolute_error: 0.0091
# Epoch 28/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1062e-04 - mean_absolute_error: 0.0076 - val_loss: 1.5578e-04 - val_mean_absolute_error: 0.0091
# Epoch 29/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.0993e-04 - mean_absolute_error: 0.0076 - val_loss: 1.5489e-04 - val_mean_absolute_error: 0.0091
# Epoch 30/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0922e-04 - mean_absolute_error: 0.0076 - val_loss: 1.5403e-04 - val_mean_absolute_error: 0.0091
# Epoch 31/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.0848e-04 - mean_absolute_error: 0.0076 - val_loss: 1.5320e-04 - val_mean_absolute_error: 0.0091
# Epoch 32/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.0773e-04 - mean_absolute_error: 0.0075 - val_loss: 1.5241e-04 - val_mean_absolute_error: 0.0091
# Epoch 33/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.0695e-04 - mean_absolute_error: 0.0075 - val_loss: 1.5166e-04 - val_mean_absolute_error: 0.0091
# Epoch 34/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.0615e-04 - mean_absolute_error: 0.0075 - val_loss: 1.5095e-04 - val_mean_absolute_error: 0.0091
# Epoch 35/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.0533e-04 - mean_absolute_error: 0.0074 - val_loss: 1.5028e-04 - val_mean_absolute_error: 0.0091
# Epoch 36/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.0450e-04 - mean_absolute_error: 0.0074 - val_loss: 1.4965e-04 - val_mean_absolute_error: 0.0091
# Epoch 37/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0367e-04 - mean_absolute_error: 0.0074 - val_loss: 1.4907e-04 - val_mean_absolute_error: 0.0091
# Epoch 38/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.0282e-04 - mean_absolute_error: 0.0073 - val_loss: 1.4854e-04 - val_mean_absolute_error: 0.0091
# Epoch 39/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.0198e-04 - mean_absolute_error: 0.0073 - val_loss: 1.4806e-04 - val_mean_absolute_error: 0.0091
# Epoch 40/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.0113e-04 - mean_absolute_error: 0.0073 - val_loss: 1.4763e-04 - val_mean_absolute_error: 0.0091
# Epoch 41/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.0029e-04 - mean_absolute_error: 0.0072 - val_loss: 1.4724e-04 - val_mean_absolute_error: 0.0091
# Epoch 42/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.9455e-05 - mean_absolute_error: 0.0072 - val_loss: 1.4690e-04 - val_mean_absolute_error: 0.0091
# Epoch 43/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.8630e-05 - mean_absolute_error: 0.0072 - val_loss: 1.4659e-04 - val_mean_absolute_error: 0.0091
# Epoch 44/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.7816e-05 - mean_absolute_error: 0.0071 - val_loss: 1.4633e-04 - val_mean_absolute_error: 0.0091
# Epoch 45/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.7015e-05 - mean_absolute_error: 0.0071 - val_loss: 1.4610e-04 - val_mean_absolute_error: 0.0091
# Epoch 46/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.6228e-05 - mean_absolute_error: 0.0071 - val_loss: 1.4591e-04 - val_mean_absolute_error: 0.0091
# Epoch 47/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.5456e-05 - mean_absolute_error: 0.0070 - val_loss: 1.4573e-04 - val_mean_absolute_error: 0.0091
# Epoch 48/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.4698e-05 - mean_absolute_error: 0.0070 - val_loss: 1.4558e-04 - val_mean_absolute_error: 0.0091
# Epoch 49/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.3956e-05 - mean_absolute_error: 0.0070 - val_loss: 1.4544e-04 - val_mean_absolute_error: 0.0091
# Epoch 50/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.3229e-05 - mean_absolute_error: 0.0069 - val_loss: 1.4530e-04 - val_mean_absolute_error: 0.0091
# Epoch 51/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.2518e-05 - mean_absolute_error: 0.0069 - val_loss: 1.4517e-04 - val_mean_absolute_error: 0.0091
# Epoch 52/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.1822e-05 - mean_absolute_error: 0.0069 - val_loss: 1.4504e-04 - val_mean_absolute_error: 0.0091
# Epoch 53/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.1141e-05 - mean_absolute_error: 0.0068 - val_loss: 1.4491e-04 - val_mean_absolute_error: 0.0091
# Epoch 54/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.0474e-05 - mean_absolute_error: 0.0068 - val_loss: 1.4476e-04 - val_mean_absolute_error: 0.0091
# Epoch 55/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.9822e-05 - mean_absolute_error: 0.0068 - val_loss: 1.4461e-04 - val_mean_absolute_error: 0.0091
# Epoch 56/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.9185e-05 - mean_absolute_error: 0.0067 - val_loss: 1.4444e-04 - val_mean_absolute_error: 0.0091
# Epoch 57/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.8562e-05 - mean_absolute_error: 0.0067 - val_loss: 1.4427e-04 - val_mean_absolute_error: 0.0091
# Epoch 58/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.7953e-05 - mean_absolute_error: 0.0067 - val_loss: 1.4408e-04 - val_mean_absolute_error: 0.0090
# Epoch 59/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.7360e-05 - mean_absolute_error: 0.0067 - val_loss: 1.4389e-04 - val_mean_absolute_error: 0.0090
# Epoch 60/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.6781e-05 - mean_absolute_error: 0.0066 - val_loss: 1.4369e-04 - val_mean_absolute_error: 0.0090
# Epoch 61/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.6218e-05 - mean_absolute_error: 0.0066 - val_loss: 1.4349e-04 - val_mean_absolute_error: 0.0090
# Epoch 62/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.5670e-05 - mean_absolute_error: 0.0066 - val_loss: 1.4330e-04 - val_mean_absolute_error: 0.0090
# Epoch 63/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.5138e-05 - mean_absolute_error: 0.0066 - val_loss: 1.4311e-04 - val_mean_absolute_error: 0.0090
# Epoch 64/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.4623e-05 - mean_absolute_error: 0.0065 - val_loss: 1.4293e-04 - val_mean_absolute_error: 0.0090
# Epoch 65/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.4124e-05 - mean_absolute_error: 0.0065 - val_loss: 1.4276e-04 - val_mean_absolute_error: 0.0089
# Epoch 66/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.3642e-05 - mean_absolute_error: 0.0065 - val_loss: 1.4260e-04 - val_mean_absolute_error: 0.0089
# Epoch 67/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.3178e-05 - mean_absolute_error: 0.0065 - val_loss: 1.4247e-04 - val_mean_absolute_error: 0.0089
# Epoch 68/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.2730e-05 - mean_absolute_error: 0.0064 - val_loss: 1.4235e-04 - val_mean_absolute_error: 0.0089
# Epoch 69/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.2300e-05 - mean_absolute_error: 0.0064 - val_loss: 1.4225e-04 - val_mean_absolute_error: 0.0089
# Epoch 70/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.1886e-05 - mean_absolute_error: 0.0064 - val_loss: 1.4218e-04 - val_mean_absolute_error: 0.0089
# Epoch 71/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.1490e-05 - mean_absolute_error: 0.0064 - val_loss: 1.4213e-04 - val_mean_absolute_error: 0.0089
# Epoch 72/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.1109e-05 - mean_absolute_error: 0.0063 - val_loss: 1.4211e-04 - val_mean_absolute_error: 0.0089
# Epoch 73/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.0745e-05 - mean_absolute_error: 0.0063 - val_loss: 1.4211e-04 - val_mean_absolute_error: 0.0089
# Epoch 74/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.0395e-05 - mean_absolute_error: 0.0063 - val_loss: 1.4214e-04 - val_mean_absolute_error: 0.0089
# Epoch 75/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.0061e-05 - mean_absolute_error: 0.0063 - val_loss: 1.4219e-04 - val_mean_absolute_error: 0.0089
# Epoch 76/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.9740e-05 - mean_absolute_error: 0.0063 - val_loss: 1.4226e-04 - val_mean_absolute_error: 0.0089
# Epoch 77/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.9433e-05 - mean_absolute_error: 0.0062 - val_loss: 1.4236e-04 - val_mean_absolute_error: 0.0089
# Epoch 78/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.9138e-05 - mean_absolute_error: 0.0062 - val_loss: 1.4249e-04 - val_mean_absolute_error: 0.0089
# Epoch 79/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.8856e-05 - mean_absolute_error: 0.0062 - val_loss: 1.4263e-04 - val_mean_absolute_error: 0.0089
# Epoch 80/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.8584e-05 - mean_absolute_error: 0.0062 - val_loss: 1.4279e-04 - val_mean_absolute_error: 0.0089
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Improved GRU Train RMSE: 387.59
# Improved GRU Test RMSE: 3431.42
# Improved GRU Train MAE: 268.87
# Improved GRU Test MAE: 2284.07

# %% [markdown]
# For the improved GRU model, I increased the number of units from 8 to 16 and added early stopping. GRU models are similar to LSTM models but are usually simpler because they use fewer gates. This can make them easier to train while still capturing sequence patterns. The purpose of this experiment was to compare whether the GRU could achieve similar or better forecasting performance than the LSTM with slightly less complexity.

# %% [markdown]
# ### Your summary

# %% [markdown]
# - I improved each recurrent model by increasing the number of recurrent units from 8 to 16 and adding early stopping. This allowed me to test whether additional model capacity improved forecasting performance while using early stopping to reduce overfitting.
#
# - The results were mixed across the recurrent architectures. The LSTM model improved from an RMSE of about 2,398 to about 2,104, making it the strongest recurrent model in the notebook. The GRU model also improved substantially, reducing RMSE from about 4,733 to about 3,431. However, the SimpleRNN model performed worse after increasing the number of units, with RMSE increasing from about 3,953 to about 5,854.
#
# - These results suggest that simply increasing model complexity does not always improve forecasting performance. More sophisticated recurrent architectures such as LSTM and GRU benefited from the additional capacity, while the SimpleRNN appeared to overfit or generalize less effectively. Among the recurrent models, the LSTM was the most accurate and produced the lowest forecasting error.
#
# - The main tradeoff observed was between model complexity and reliability. Larger recurrent models can capture more temporal patterns, but they are harder to tune and do not guarantee better performance. Early stopping helped prevent unnecessary training and improved stability for the LSTM and GRU models.

# %% [markdown]
# _______________________________________________________________________________________________________________________________
#
# _______________________________________________________________________________________________________________________________

# %% [markdown]
# ### Do you need RNN for time series data?
#
# #### XGB with lagged features

# %% [markdown]
# Plotting function for nonscaled models

# %%
# Generic prediction plotting function for models already on the original scale

def plot_predictions(actual, predicted, title):

    plt.figure(figsize=(10, 4))

    plt.plot(actual, label="Actual")
    plt.plot(predicted, label="Predicted")

    plt.title(title)
    plt.xlabel("Test time index")
    plt.ylabel("Bitcoin Close Price (USD)")

    plt.ticklabel_format(style="plain", axis="y")

    plt.legend()
    plt.show()

# %% [markdown]
# XGB Data preparation

# %%
# Create lagged features for XGBoost

xgb_data = bitcoin[["date"] + features].copy()

lag_days = 10

for lag in range(1, lag_days + 1):
    for col in features:
        xgb_data[f"{col}_lag{lag}"] = xgb_data[col].shift(lag)

xgb_data["target_close_USD"] = xgb_data["close_USD"]

xgb_data = xgb_data.dropna().reset_index(drop=True)

xgb_data.head()
# Out:
#         date  open_USD  high_USD  low_USD  close_USD  volume  open_USD_lag1  \
# 0 2018-05-17   8330.00   8464.00  7979.00    8041.46   25439        8462.00
# 1 2018-05-18   8038.82   8273.21  7911.90    8239.81   23476        8330.00
# 2 2018-05-19   8238.01   8390.80  8095.73    8233.49   17193        8038.82
# 3 2018-05-20   8233.49   8609.00  8163.90    8526.98   19957        8238.01
# 4 2018-05-21   8526.97   8595.31  8305.00    8381.24   21516        8233.49
#
#    high_USD_lag1  low_USD_lag1  close_USD_lag1  ...  high_USD_lag9  \
# 0        8488.00       8083.01         8330.00  ...        9475.70
# 1        8464.00       7979.00         8041.46  ...        9390.00
# 2        8273.21       7911.90         8239.81  ...        9395.12
# 3        8390.80       8095.73         8233.49  ...        9016.80
# 4        8609.00       8163.90         8526.98  ...        8646.88
#
#    low_USD_lag9  close_USD_lag9  volume_lag9  open_USD_lag10  high_USD_lag10  \
# 0       9060.54         9187.56      25533.0         9661.02         9689.67
# 1       8965.00         9310.00      25673.0         9365.00         9475.70
# 2       8970.00         9002.20      25055.0         9178.00         9390.00
# 3       8341.00         8400.00      48227.0         9310.00         9395.12
# 4       8153.00         8465.94      40241.0         9002.21         9016.80
#
#    low_USD_lag10  close_USD_lag10  volume_lag10  target_close_USD
# 0        9181.00          9365.00       33787.0           8041.46
# 1        9060.54          9187.56       25533.0           8239.81
# 2        8965.00          9310.00       25673.0           8233.49
# 3        8970.00          9002.20       25055.0           8526.98
# 4        8341.00          8400.00       48227.0           8381.24
#
# [5 rows x 57 columns]

# %% [markdown]
# XGB train test preparation

# %%
# Prepare XGBoost train/test data

xgb_features = [
    col for col in xgb_data.columns
    if "lag" in col
]

X_xgb = xgb_data[xgb_features]
y_xgb = xgb_data["target_close_USD"]

train_size_xgb = int(len(xgb_data) * 0.8)

trainX_xgb = X_xgb.iloc[:train_size_xgb]
testX_xgb = X_xgb.iloc[train_size_xgb:]

trainY_xgb = y_xgb.iloc[:train_size_xgb]
testY_xgb = y_xgb.iloc[train_size_xgb:]

print("trainX_xgb shape:", trainX_xgb.shape)
print("testX_xgb shape:", testX_xgb.shape)
print("trainY_xgb shape:", trainY_xgb.shape)
print("testY_xgb shape:", testY_xgb.shape)
# Out:
# trainX_xgb shape: (792, 50)
# testX_xgb shape: (198, 50)
# trainY_xgb shape: (792,)
# testY_xgb shape: (198,)

# %% [markdown]
# Build & train model

# %%
# Build and train baseline XGBoost model

from xgboost import XGBRegressor

xgb_model = XGBRegressor(
    n_estimators=100,
    max_depth=3,
    learning_rate=0.1,
    objective="reg:squarederror",
    random_state=42
)

xgb_model.fit(
    trainX_xgb,
    trainY_xgb
)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=3,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=100,
#              n_jobs=None, num_parallel_tree=None, ...)

# %% [markdown]
# Evaluating on test data

# %%
# Evaluate XGBoost baseline on held-out future test data

xgb_test_pred = xgb_model.predict(testX_xgb)

xgb_rmse = np.sqrt(mean_squared_error(testY_xgb, xgb_test_pred))
xgb_mae = mean_absolute_error(testY_xgb, xgb_test_pred)

print(f"Baseline XGBoost Test RMSE: {xgb_rmse:.2f}")
print(f"Baseline XGBoost Test MAE: {xgb_mae:.2f}")
# Out:
# Baseline XGBoost Test RMSE: 10490.81
# Baseline XGBoost Test MAE: 6340.83

# %%
# Visualize baselineXGBoost predictions

plot_predictions(
    testY_xgb.values,
    xgb_test_pred,
    "Baseline XGBoost Test Predictions"
)

# %% [markdown]
# Modifying the XGB target to percent change instead of raw price

# %%
# Improved XGBoost: predict next-day percent change instead of raw price

xgb_return_data = bitcoin[["date"] + features].copy()

xgb_return_data["close_return"] = (
    xgb_return_data["close_USD"]
    .pct_change()
)                                                               # calculate daily percent return

lag_days = 10                                                   # use previous 10 days as predictors

for lag in range(1, lag_days + 1):

    for col in features:
        xgb_return_data[f"{col}_lag{lag}"] = (
            xgb_return_data[col]
            .shift(lag)
        )                                                       # previous feature values become lag predictors

    xgb_return_data[f"close_return_lag{lag}"] = (
        xgb_return_data["close_return"]
        .shift(lag)
    )                                                           # include lagged returns as predictors

xgb_return_data["target_return"] = (
    xgb_return_data["close_return"]
    .shift(-1)
)                                                               # predict next-day return

xgb_return_data["current_close_USD"] = (
    xgb_return_data["close_USD"]
)                                                               # keep current close price for reconstruction later

xgb_return_data = (
    xgb_return_data
    .dropna()
    .reset_index(drop=True)
)                                                               # remove rows without sufficient lag history

xgb_return_features = [
    col for col in xgb_return_data.columns
    if "lag" in col
]                                                               # use lagged values as predictors

X_xgb_return = xgb_return_data[xgb_return_features]
y_xgb_return = xgb_return_data["target_return"]

train_size_xgb_return = int(len(xgb_return_data) * 0.8)        # chronological 80/20 split

trainX_xgb_return = X_xgb_return.iloc[:train_size_xgb_return]
testX_xgb_return = X_xgb_return.iloc[train_size_xgb_return:]

trainY_xgb_return = y_xgb_return.iloc[:train_size_xgb_return]
testY_xgb_return = y_xgb_return.iloc[train_size_xgb_return:]

test_current_close = (
    xgb_return_data["current_close_USD"]
    .iloc[train_size_xgb_return:]
)                                                               # current price used to reconstruct next-day prediction

xgb_return_model = XGBRegressor(
    n_estimators=300,                                           # more trees for stronger learning
    max_depth=2,                                                # shallow trees reduce overfitting
    learning_rate=0.03,                                         # smaller learning steps
    subsample=0.8,                                              # random row sampling
    colsample_bytree=0.8,                                       # random feature sampling
    objective="reg:squarederror",
    random_state=42
)

xgb_return_model.fit(
    trainX_xgb_return,
    trainY_xgb_return
)

xgb_return_pred = xgb_return_model.predict(
    testX_xgb_return
)                                                               # predict next-day percent return

xgb_return_price_pred = (
    test_current_close.values * (1 + xgb_return_pred)
)                                                               # convert predicted return back to predicted price

xgb_return_price_actual = (
    test_current_close.values * (1 + testY_xgb_return.values)
)                                                               # actual next-day price

xgb_return_rmse = np.sqrt(
    mean_squared_error(
        xgb_return_price_actual,
        xgb_return_price_pred
    )
)

xgb_return_mae = mean_absolute_error(
    xgb_return_price_actual,
    xgb_return_price_pred
)

print(f"Improved XGBoost Test RMSE: {xgb_return_rmse:.2f}")
print(f"Improved XGBoost Test MAE: {xgb_return_mae:.2f}")

plot_predictions(
    xgb_return_price_actual,
    xgb_return_price_pred,
    "Improved XGBoost Return-Based Test Predictions"
)
# Out:
# Improved XGBoost Test RMSE: 883.70
# Improved XGBoost Test MAE: 537.31

# %%
# Compare baseline model performance

simple_rnn_rmse, simple_rnn_mae = evaluate_metrics(
    simple_rnn_model,
    testX_bitcoin,
    testY_bitcoin,
    scaler_bitcoin,
    target_index
)

lstm_rmse, lstm_mae = evaluate_metrics(
    lstm_model,
    testX_bitcoin,
    testY_bitcoin,
    scaler_bitcoin,
    target_index
)

gru_rmse, gru_mae = evaluate_metrics(
    gru_model,
    testX_bitcoin,
    testY_bitcoin,
    scaler_bitcoin,
    target_index
)

model_comparison = pd.DataFrame({
    "Model": [
        "SimpleRNN",
        "LSTM",
        "GRU",
        "XGBoost raw price target",
        "XGBoost return target"
    ],

    "RMSE": [
        simple_rnn_rmse,
        lstm_rmse,
        gru_rmse,
        xgb_rmse,
        xgb_return_rmse
    ],

    "MAE": [
        simple_rnn_mae,
        lstm_mae,
        gru_mae,
        xgb_mae,
        xgb_return_mae
    ]
})

model_comparison.sort_values("RMSE")
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
#                       Model          RMSE          MAE
# 4     XGBoost return target    883.702942   537.313845
# 1                      LSTM   2398.134689  1580.108710
# 0                 SimpleRNN   3953.112066  2409.817631
# 2                       GRU   4732.627512  3248.332966
# 3  XGBoost raw price target  10490.806519  6340.832358

# %% [markdown]
# comparing all

# %%
# Compare baseline recurrent models, improved recurrent models, and XGBoost models

simple_rnn_rmse, simple_rnn_mae = evaluate_metrics(
    simple_rnn_model,
    testX_bitcoin,
    testY_bitcoin,
    scaler_bitcoin,
    target_index
)

lstm_rmse, lstm_mae = evaluate_metrics(
    lstm_model,
    testX_bitcoin,
    testY_bitcoin,
    scaler_bitcoin,
    target_index
)

gru_rmse, gru_mae = evaluate_metrics(
    gru_model,
    testX_bitcoin,
    testY_bitcoin,
    scaler_bitcoin,
    target_index
)

improved_simple_rnn_rmse, improved_simple_rnn_mae = evaluate_metrics(
    improved_simple_rnn_model,
    testX_bitcoin,
    testY_bitcoin,
    scaler_bitcoin,
    target_index
)

improved_lstm_rmse, improved_lstm_mae = evaluate_metrics(
    improved_lstm_model,
    testX_bitcoin,
    testY_bitcoin,
    scaler_bitcoin,
    target_index
)

improved_gru_rmse, improved_gru_mae = evaluate_metrics(
    improved_gru_model,
    testX_bitcoin,
    testY_bitcoin,
    scaler_bitcoin,
    target_index
)

model_comparison = pd.DataFrame({
    "Model": [
        "Baseline SimpleRNN",
        "Improved SimpleRNN",
        "Baseline LSTM",
        "Improved LSTM",
        "Baseline GRU",
        "Improved GRU",
        "XGBoost raw price target",
        "XGBoost return target"
    ],

    "RMSE": [
        simple_rnn_rmse,
        improved_simple_rnn_rmse,
        lstm_rmse,
        improved_lstm_rmse,
        gru_rmse,
        improved_gru_rmse,
        xgb_rmse,
        xgb_return_rmse
    ],

    "MAE": [
        simple_rnn_mae,
        improved_simple_rnn_mae,
        lstm_mae,
        improved_lstm_mae,
        gru_mae,
        improved_gru_mae,
        xgb_mae,
        xgb_return_mae
    ]
})

model_comparison.sort_values("RMSE")
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
#                       Model          RMSE          MAE
# 7     XGBoost return target    883.702942   537.313845
# 3             Improved LSTM   2103.846386  1399.849332
# 2             Baseline LSTM   2398.134689  1580.108710
# 5              Improved GRU   3431.422864  2284.072286
# 0        Baseline SimpleRNN   3953.112066  2409.817631
# 4              Baseline GRU   4732.627512  3248.332966
# 1        Improved SimpleRNN   5853.846021  3886.100874
# 6  XGBoost raw price target  10490.806519  6340.832358

# %% [markdown]
# The final comparison included the baseline recurrent models, improved recurrent models, and two XGBoost forecasting approaches. Model performance was evaluated using RMSE and MAE, where lower values indicate more accurate forecasts.
#
# - The best overall model was the **XGBoost model trained on return targets**, which achieved an RMSE of about 884 and an MAE of about 537. This performance was substantially better than all recurrent neural network models. The strongest neural network model was the improved LSTM, which achieved an RMSE of about 2,104 and an MAE of about 1,400.
#
# - One interesting finding was that forecasting returns rather than raw prices dramatically improved XGBoost performance. The XGBoost model trained directly on raw Bitcoin prices produced the worst results, with an RMSE above 10,000. This suggests that the preprocessing choice and target definition had a larger impact on performance than increasing model complexity alone.
#
# - Among the recurrent models, LSTM was the easiest to justify as the best architecture because it consistently produced lower forecasting error than SimpleRNN and GRU. The SimpleRNN was the simplest model to train, but increasing its complexity did not improve performance. The GRU improved after tuning but still did not match the LSTM.
#
# Overall, the most important thing I learned was that preprocessing decisions and target engineering can be just as important as model selection. More complex models are not automatically better, and careful feature or target design can produce larger gains than simply increasing the size of a neural network.
